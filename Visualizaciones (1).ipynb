# %% [markdown]
# ## Visualizacion de datos

# %%
Importamos las librerias

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
Importamos el csv utilizando la libreria pandas

# %%
df_lluvias = pd.read_csv('Datasets/pune_1965_to_2002.csv')

# %%
df_lluvias.head(3)
# Out:
#    Year    Jan    Feb   Mar     Apr     May      Jun      Jul      Aug  \
# 0  1965  0.029  0.069  0.00  21.667  17.859  102.111  606.071  402.521
# 1  1966  0.905  0.000  0.00   2.981  63.008   94.088  481.942   59.386
# 2  1967  0.248  3.390  1.32  13.482  11.116  251.314  780.006  181.069
#
#        Sep     Oct     Nov     Dec
# 0   69.511   5.249  16.232  22.075
# 1  150.624   1.308  41.214   4.132
# 2  183.757  50.404   8.393  37.685

# %%
df_lluvias.index = df_lluvias['Year']
df_lluvias = df_lluvias.drop('Year', axis='columns')

# %%
x = df_lluvias.index
y = df_lluvias.sum(axis='columns')

# %%
y
# Out:
# Year
# 1965    1263.394
# 1966     899.588
# 1967    1522.184
# 1968    1086.237
# 1969    1739.022
# 1970    1273.507
# 1971    1176.612
# 1972     710.475
# 1973    1570.073
# 1974    1425.876
# 1975    1777.838
# 1976    1941.167
# 1977    1202.154
# 1978    1168.583
# 1979    1769.187
# 1980    1268.185
# 1981    1562.761
# 1982     943.087
# 1983    1616.948
# 1984    1538.961
# 1985    1214.852
# 1986    1267.969
# 1987    1197.999
# 1988    1822.649
# 1989    1400.024
# 1990    1766.294
# 1991    1497.256
# 1992    1323.883
# 1993    1210.252
# 1994    1987.689
# 1995    1209.068
# 1996    1631.331
# 1997    1844.840
# 1998    1603.243
# 1999    1235.683
# 2000    1094.062
# 2001    1045.825
# 2002    1024.881
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, label='Precipitaciones acumuladas')
ax.set_xlabel('Año')                  
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(8,4))
precipitaciones_acumuladas = df_lluvias.sum()
ax.bar(df_lluvias.columns, precipitaciones_acumuladas)
ax.set_title('Precipitaciones acumuladas desde 1965 a 2002, según el mes')
ax.set_ylabel('Precipitación total (mm.)')
ax.set_xlabel('Mes')
# Out:
# Text(0.5, 0, 'Mes')

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True, sharey=True)  
ax[0].plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax[1].plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
ax[2].plot(df_lluvias.index, df_lluvias['Mar'], label='Precipitaciones de marzo', color='C2')
ax[0].set_title('Precipitaciones de los primeros tres meses del año') 
ax[2].set_xlabel('Año')  
ax[1].set_ylabel('Precipitación (mm.)')

ax[0].legend()  
ax[1].legend()
ax[2].legend()

# %%
fig, ax = plt.subplots(figsize=(10, 4))  
ax.plot(df_lluvias.index, df_lluvias['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvias.index, df_lluvias['Feb'], label='Precipitaciones de febrero', color='C1')
maximo_enero = df_lluvias['Jan'].max()
maximo_febrero =  df_lluvias['Feb'].max()
ax.axhline(maximo_enero, color='red', linestyle='--', alpha=0.5,    linewidth=3, label='Máxima de enero')
ax.axhline(maximo_febrero, color='green', linestyle='--', alpha=0.5, linewidth=3, label='Máxima de febrero')
ax.set_xlabel('Año')  
ax.set_ylabel('Precipitación (mm.)') 
ax.set_title('Precipitaciones de enero y febrero')     
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
ax.legend(loc= 'best')

# %%
Importamos el csv que contien datos sobre empleados de una organización

# %%
df_salarios = pd.read_csv('Datasets/HRDataset_v14.csv',sep=',')
df_salarios.head(3)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
#
# [3 rows x 36 columns]

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.hist(x= df_salarios.Salary, bins=None, density=False, orientation='vertical')
ax.set_xlabel('Salario')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma de Salario')
# Out:
# Text(0.5, 1.0, 'Histograma de Salario')

# %% [markdown]
# Utilizamos el dataset penguins que contiene la libreria seaborn

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %%
Utilizamos el dataset tips que contiene la libreria seaborn

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# Utilizamos el dataset exercise que contiene la libreria seaborn

# %%
df_ejercicio = sns.load_dataset('exercise')
df_ejercicio.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
df_ejercicio = df_ejercicio.drop('Unnamed: 0', axis='columns')

# %%
df_ejercicio.head(3)
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest

# %%
df_30_min = df_ejercicio[df_ejercicio['time'] == '30 min']
df_30_min.head(3)
# Out:
#    id     diet  pulse    time  kind
# 2   1  low fat     88  30 min  rest
# 5   2  low fat     93  30 min  rest
# 8   3  low fat     94  30 min  rest

# %%
ax = sns.displot(data=df_30_min, x='pulse', kind = 'kde', hue='kind', fill=True)
ax.set(xlabel='Frecuencia Cardíaca', ylabel='Densidad', title='Distribución de las pulsaciones')

# %% [markdown]
# Cargamos el csv Time Series Data, que contiene información sobre los precios de la criptomoneda Bitcoin

# %%
data=pd.read_csv('Datasets/Time Series Data.csv') # Leer el archivo
fecha=data['Date'] # extraer la fecha
precio=data['Close'] # extraer el precio 
plt.plot_date(fecha, precio, linestyle='solid') # Graficar la serie de tiempo
plt.gcf().autofmt_xdate() # Darle formato fecha al eje x
plt.title('Precios Bitcoin')
plt.xlabel('Fecha')
plt.ylabel('Precio de cierre')
plt.tight_layout() # Ajustar los ejes 
plt.show() # mostrar la grafica

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,4))
sns.scatterplot(x=data.Close, y= data.Open)
plt.title('Relacion entre Precio apertura y cierre')
plt.xlabel('Precio de Cierre')
plt.ylabel('Precio de apertura')
# Out:
# Text(0, 0.5, 'Precio de apertura')
